# %% [markdown]
# # EN705603 Creating AI Enabled Systems
# # Assignment 3 Charles Xia

# %% [markdown]
# ---

# %% [raw]
# Using the Amazon musical instrument review data on Kaggle, retrieve the summary column, perform tokenization, stemming, and lemmatization. Construct results of text processing as an jupyter notebook.

# %%
import pandas as pd
musical_instruments_review_df = pd.read_csv("Musical_instruments_reviews.csv")
musical_instruments_review_df
# Out:
#            reviewerID        asin  \
# 0      A2IBPI20UZIR0U  1384719342
# 1      A14VAT5EAX3D9S  1384719342
# 2      A195EZSQDW3E21  1384719342
# 3      A2C00NNG1ZQQG2  1384719342
# 4       A94QU4C90B1AX  1384719342
# ...               ...         ...
# 10256  A14B2YH83ZXMPP  B00JBIVXGC
# 10257   A1RPTVW5VEOSI  B00JBIVXGC
# 10258   AWCJ12KBO5VII  B00JBIVXGC
# 10259  A2Z7S8B5U4PAKJ  B00JBIVXGC
# 10260  A2WA8TDCTGUADI  B00JBIVXGC
#
#                                            reviewerName   helpful  \
# 0      cassandra tu "Yeah, well, that's just like, u...    [0, 0]
# 1                                                  Jake  [13, 14]
# 2                         Rick Bennette "Rick Bennette"    [1, 1]
# 3                             RustyBill "Sunday Rocker"    [0, 0]
# 4                                         SEAN MASLANKA    [0, 0]
# ...                                                 ...       ...
# 10256                                   Lonnie M. Adams    [0, 0]
# ...

# %%
summary_reviews = musical_instruments_review_df["summary"]
summary_reviews
# Out:
# 0                                                     good
# 1                                                     Jake
# 2                                     It Does The Job Well
# 3                            GOOD WINDSCREEN FOR THE MONEY
# 4                    No more pops when I record my vocals.
#                                ...
# 10256                                           Five Stars
# 10257    Long life, and for some players, a good econom...
# 10258                                     Good for coated.
# 10259                                          Taylor Made
# 10260    These strings are really quite good, but I wou...
# Name: summary, Length: 10261, dtype: object

# %%
import nltk
# nltk.download('punkt')

# %%
# nltk.word_tokenize(summary_reviews)
work_tokenize_list = [nltk.word_tokenize(word) for word in summary_reviews]
work_tokenize_list[0:25] #displaying a sample
# Out:
# [['good'],
#  ['Jake'],
#  ['It', 'Does', 'The', 'Job', 'Well'],
#  ['GOOD', 'WINDSCREEN', 'FOR', 'THE', 'MONEY'],
#  ['No', 'more', 'pops', 'when', 'I', 'record', 'my', 'vocals', '.'],
#  ['The', 'Best', 'Cable'],
#  ['Monster', 'Standard', '100', '-', '21', "'", 'Instrument', 'Cable'],
#  ['Did', "n't", 'fit', 'my', '1996', 'Fender', 'Strat', '...'],
#  ['Great', 'cable'],
#  ['Best', 'Instrument', 'Cables', 'On', 'The', 'Market'],
#  ['One',
#   'of',
#   'the',
#   'best',
#   'instrument',
#   'cables',
#   'within',
#   'the',
#   'brand'],
#  ['It', 'works', 'great', 'but', 'I', 'hardly', 'use', 'it', '.'],
#  ['HAS', 'TO', 'GET', 'USE', 'TO', 'THE', 'SIZE'],
#  ['awesome'],
#  ['It', 'works', '!'],
#  ['Definitely', 'Not', 'For', 'The', 'Seasoned', 'Piano', 'Player'],
#  ['Durable', 'Instrument', 'Cable'],
#  ['fender', '18', 'ft.', 'Cali', 'clear', '...'],
#  ['So',
#   'far',
#   'so',
#   'good',
#   '.',
#   'Will',
#   'revisit',
#   'at',
#   'the',
#   '6',
# ...

# %%
from nltk.stem.porter import PorterStemmer

# %%
porter_stem_list = [PorterStemmer().stem(word) for word in summary_reviews]
porter_stem_list[0:25] # displaying a sample
# Out:
# ['good',
#  'jake',
#  'it does the job wel',
#  'good windscreen for the money',
#  'no more pops when i record my vocals.',
#  'the best c',
#  "monster standard 100 - 21' instrument c",
#  "didn't fit my 1996 fender strat...",
#  'great cabl',
#  'best instrument cables on the market',
#  'one of the best instrument cables within the brand',
#  'it works great but i hardly use it.',
#  'has to get use to the s',
#  'awesom',
#  'it works!',
#  'definitely not for the seasoned piano play',
#  'durable instrument c',
#  'fender 18 ft. cali clear...',
#  'so far so good.  will revisit at the 6 month mark ;)',
#  'add california to the name and i jump!',
#  'cheap and cool looking, good length',
#  'fender 18 feet california clear instrument cable - lake placid blu',
#  'guitar c',
#  'quality cable!',
#  'i got great pricing, but still a really good product']

# %%
from nltk.stem.wordnet import WordNetLemmatizer
# nltk.download('wordnet')

# %%
lemmatize_list = [WordNetLemmatizer().lemmatize(word,'v') for word in summary_reviews]
lemmatize_list[0:25] #displaying a sample
# Out:
# ['good',
#  'Jake',
#  'It Does The Job Well',
#  'GOOD WINDSCREEN FOR THE MONEY',
#  'No more pops when I record my vocals.',
#  'The Best Cable',
#  "Monster Standard 100 - 21' Instrument Cable",
#  "Didn't fit my 1996 Fender Strat...",
#  'Great cable',
#  'Best Instrument Cables On The Market',
#  'One of the best instrument cables within the brand',
#  'It works great but I hardly use it.',
#  'HAS TO GET USE TO THE SIZE',
#  'awesome',
#  'It works!',
#  'Definitely Not For The Seasoned Piano Player',
#  'Durable Instrument Cable',
#  'fender 18 ft. Cali clear...',
#  'So far so good.  Will revisit at the 6 month mark ;)',
#  'Add California to the name and I jump!',
#  'Cheap and cool looking, good length',
#  'Fender 18 Feet California Clear Instrument Cable - Lake Placid Blue',
#  'Guitar Cable',
#  'Quality cable!',
#  'I Got Great Pricing, But Still a Really Good Product']

# %%
result = zip(work_tokenize_list,porter_stem_list,lemmatize_list)
result

# %%
for word in result:
    print(f"Tokenize: {word[0]}, Porter Stem: {word[1]}, Lemmatize: {word[2]}")
# Out:
# Tokenize: ['good'], Porter Stem: good, Lemmatize: good
# Tokenize: ['Jake'], Porter Stem: jake, Lemmatize: Jake
# Tokenize: ['It', 'Does', 'The', 'Job', 'Well'], Porter Stem: it does the job wel, Lemmatize: It Does The Job Well
# Tokenize: ['GOOD', 'WINDSCREEN', 'FOR', 'THE', 'MONEY'], Porter Stem: good windscreen for the money, Lemmatize: GOOD WINDSCREEN FOR THE MONEY
# Tokenize: ['No', 'more', 'pops', 'when', 'I', 'record', 'my', 'vocals', '.'], Porter Stem: no more pops when i record my vocals., Lemmatize: No more pops when I record my vocals.
# Tokenize: ['The', 'Best', 'Cable'], Porter Stem: the best c, Lemmatize: The Best Cable
# Tokenize: ['Monster', 'Standard', '100', '-', '21', "'", 'Instrument', 'Cable'], Porter Stem: monster standard 100 - 21' instrument c, Lemmatize: Monster Standard 100 - 21' Instrument Cable
# ...
